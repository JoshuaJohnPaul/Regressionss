# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
oil = pd.read_csv("C:/Users/divya/Desktop/og.csv")
original_dataset = oil

# %%
oil
# Out:
#           cty_name  iso3numeric   id  year       eiacty  oil_prod32_14  \
# 0      Afghanistan            4  AFG  1932  Afghanistan            NaN
# 1      Afghanistan            4  AFG  1933  Afghanistan            NaN
# 2      Afghanistan            4  AFG  1934  Afghanistan            NaN
# 3      Afghanistan            4  AFG  1935  Afghanistan            NaN
# 4      Afghanistan            4  AFG  1936  Afghanistan            NaN
# ...            ...          ...  ...   ...          ...            ...
# 15516     Zimbabwe          716  ZWE  2010     Zimbabwe            0.0
# 15517     Zimbabwe          716  ZWE  2011     Zimbabwe            0.0
# 15518     Zimbabwe          716  ZWE  2012     Zimbabwe            0.0
# 15519     Zimbabwe          716  ZWE  2013     Zimbabwe            0.0
# 15520     Zimbabwe          716  ZWE  2014     Zimbabwe            0.0
#
#        oil_price_2000  oil_price_nom  oil_value_nom  oil_value_2000  ...  \
# ...

# %%
ss=oil.drop("cty_name",axis=1)

# %%
c=ss.drop("id",axis=1)

# %%
d=c.drop("eiacty",axis=1)
d
# Out:
#        iso3numeric  year  oil_prod32_14  oil_price_2000  oil_price_nom  \
# 0                4  1932            NaN       10.860860       0.870000
# 1                4  1933            NaN        8.815239       0.670000
# 2                4  1934            NaN       12.715790       1.000000
# 3                4  1935            NaN       12.039690       0.970000
# 4                4  1936            NaN       13.383210       1.090000
# ...            ...   ...            ...             ...            ...
# 15516          716  2010            0.0       62.778052      79.495534
# 15517          716  2011            0.0       85.170708     111.255598
# 15518          716  2012            0.0       83.754465     111.669702
# 15519          716  2013            0.0       80.319530     108.658518
# 15520          716  2014            0.0       71.972588      98.946008
#
#        oil_value_nom  oil_value_2000  oil_value_2014  gas_prod55_14  \
# ...

# %%
d.mean(axis=0)
# Out:
# iso3numeric                     4.401021e+02
# year                            1.973000e+03
# oil_prod32_14                   1.834108e+07
# oil_price_2000                  2.651308e+01
# oil_price_nom                   1.940738e+01
# oil_value_nom                   4.049737e+09
# oil_value_2000                  4.777023e+09
# oil_value_2014                  6.567325e+09
# gas_prod55_14                   1.007020e+02
# gas_price_2000_mboe             1.403597e+07
# gas_price_2000                  3.586465e+00
# gas_price_nom                   1.448253e+00
# gas_value_nom                   1.796270e+09
# gas_value_2000                  2.130068e+09
# gas_value_2014                  2.928361e+09
# oil_gas_value_nom               5.544579e+09
# oil_gas_value_2000              6.549973e+09
# oil_gas_value_2014              9.004730e+09
# oil_gas_valuePOP_nom            5.060331e+02
# oil_gas_valuePOP_2000           7.214833e+02
# oil_gas_valuePOP_2014           9.918761e+02
# ...

# %%
d.median(axis=0)
# Out:
# iso3numeric                     4.220000e+02
# year                            1.973000e+03
# oil_prod32_14                   4.980000e+04
# oil_price_2000                  1.406798e+01
# oil_price_nom                   3.290000e+00
# oil_value_nom                   2.064857e+06
# oil_value_2000                  7.171990e+06
# oil_value_2014                  9.859862e+06
# gas_prod55_14                   0.000000e+00
# gas_price_2000_mboe             1.472159e+07
# gas_price_2000                  3.022647e+00
# gas_price_nom                   2.200000e-01
# gas_value_nom                   0.000000e+00
# gas_value_2000                  0.000000e+00
# gas_value_2014                  0.000000e+00
# oil_gas_value_nom               4.810003e+06
# oil_gas_value_2000              1.561276e+07
# oil_gas_value_2014              2.146400e+07
# oil_gas_valuePOP_nom            3.425533e-01
# oil_gas_valuePOP_2000           1.130745e+00
# oil_gas_valuePOP_2014           1.554518e+00
# ...

# %%
d.mode()
# Out:
#     iso3numeric  year  oil_prod32_14  oil_price_2000  oil_price_nom  \
# 0         736.0  1932            0.0        7.879107            1.8
# 1           NaN  1933            NaN        8.347174            NaN
# 2           NaN  1934            NaN        8.797903            NaN
# 3           NaN  1935            NaN        9.161955            NaN
# 4           NaN  1936            NaN        9.413322            NaN
# ..          ...   ...            ...             ...            ...
# 78          NaN  2010            NaN             NaN            NaN
# 79          NaN  2011            NaN             NaN            NaN
# 80          NaN  2012            NaN             NaN            NaN
# 81          NaN  2013            NaN             NaN            NaN
# 82          NaN  2014            NaN             NaN            NaN
#
#     oil_value_nom  oil_value_2000  oil_value_2014  gas_prod55_14  \
# 0             0.0             0.0             0.0            0.0
# ...

# %%
max (cars["mpg"])-min(cars["mpg"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'mpg'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
d.boxplot(column="oil_price_2000",return_type="axes",figsize=(8,8))


plt.text(x=0.74,y=22.5,s="3rd.Q")
plt.text(x=0.8,y=18.75,s="Median")
plt.text(x=0.75,y=15.5,s="1st.Q")
plt.text(x=0.9,y=10,s="min")
plt.text(x=0.9,y=33.5,s="max")
plt.text(x=0.7,y=19.5,s="IOR",rotation=0,size=25);

# %%
cars["mpg"].var()
# Out:
# 36.32410282258065

# %%
cars["mpg"].std()
# Out:
# 6.026948052089105

# %%
cars["mpg"].skew()
# Out:
# 0.6723771376290805

# %%
cars["mpg"].kurt()
# Out:
# -0.0220062914240855
